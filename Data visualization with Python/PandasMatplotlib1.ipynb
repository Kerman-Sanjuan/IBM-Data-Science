# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('/Users/kerman/Documents/Data Science/Datasets/United Nations Migration/UN_MigFlow_All_CountryFiles/Spain.xlsx', skiprows=range(20),
                       skipfooter=2)

# %%
df
# Out:
#           Type Coverage                               AreaName  \
# 0    Emigrants     Both                                 Africa
# 1    Emigrants     Both                                 Africa
# 2    Emigrants     Both                                 Africa
# 3    Emigrants     Both                                 Africa
# 4    Emigrants     Both                                 Africa
# 5    Emigrants     Both                           Africa Total
# 6    Emigrants     Both                                   Asia
# 7    Emigrants     Both                                   Asia
# 8    Emigrants     Both                                   Asia
# 9    Emigrants     Both                                   Asia
# 10   Emigrants     Both                                   Asia
# 11   Emigrants     Both                             Asia Total
# 12   Emigrants     Both                                 Europe
# 13   Emigrants     Both                                 Europe
# ...

# %%
df.replace("..",np.nan,inplace = True)

# %%
df
# Out:
#           Type Coverage                               AreaName  \
# 0    Emigrants     Both                                 Africa
# 1    Emigrants     Both                                 Africa
# 2    Emigrants     Both                                 Africa
# 3    Emigrants     Both                                 Africa
# 4    Emigrants     Both                                 Africa
# 5    Emigrants     Both                           Africa Total
# 6    Emigrants     Both                                   Asia
# 7    Emigrants     Both                                   Asia
# 8    Emigrants     Both                                   Asia
# 9    Emigrants     Both                                   Asia
# 10   Emigrants     Both                                   Asia
# 11   Emigrants     Both                             Asia Total
# 12   Emigrants     Both                                 Europe
# 13   Emigrants     Both                                 Europe
# ...

# %%
df.isnull().sum()
# Out:
# Type         0
# Coverage     0
# AreaName     0
# RegName      9
# 1980        54
# 1981        54
# 1982        54
# 1983        54
# 1984        54
# 1985        40
# 1986        41
# 1987        41
# 1988        35
# 1989        35
# 1990        34
# 1991        34
# 1992        32
# 1993        32
# 1994        30
# 1995        30
# 1996        30
# 1997        30
# 1998        28
# 1999        29
# 2000        28
# 2001        29
# 2002         3
# 2003         3
# 2004         2
# 2005         3
# 2006         3
# 2007         3
# 2008         1
# 2009         3
# 2010         0
# 2011         2
# 2012         0
# 2013        54
# dtype: int64

# %%
df.drop([1980],axis = 1)
# Out:
#           Type Coverage                               AreaName  \
# 0    Emigrants     Both                                 Africa
# 1    Emigrants     Both                                 Africa
# 2    Emigrants     Both                                 Africa
# 3    Emigrants     Both                                 Africa
# 4    Emigrants     Both                                 Africa
# 5    Emigrants     Both                           Africa Total
# 6    Emigrants     Both                                   Asia
# 7    Emigrants     Both                                   Asia
# 8    Emigrants     Both                                   Asia
# 9    Emigrants     Both                                   Asia
# 10   Emigrants     Both                                   Asia
# 11   Emigrants     Both                             Asia Total
# 12   Emigrants     Both                                 Europe
# 13   Emigrants     Both                                 Europe
# ...

# %%
# Out:
#           Type Coverage                               AreaName  \
# 0    Emigrants     Both                                 Africa
# 1    Emigrants     Both                                 Africa
# 2    Emigrants     Both                                 Africa
# 3    Emigrants     Both                                 Africa
# 4    Emigrants     Both                                 Africa
# 5    Emigrants     Both                           Africa Total
# 6    Emigrants     Both                                   Asia
# 7    Emigrants     Both                                   Asia
# 8    Emigrants     Both                                   Asia
# 9    Emigrants     Both                                   Asia
# 10   Emigrants     Both                                   Asia
# 11   Emigrants     Both                             Asia Total
# 12   Emigrants     Both                                 Europe
# 13   Emigrants     Both                                 Europe
# ...
